# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size']=14
plt.rcParams['figure.figsize']=(10,8)
plt.rcParams['figure.facecolor']='yellow'

# %%
data=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
data_columns=['Country','Region','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Generosity','Trust (Government Corruption)']

# %%
data = data[data_columns].copy()

# %%
happy_df= data.rename({'Country':'country_name','Region':'region','Happiness Score':'happiness_score','Economy (GDP per Capita)':'Economy_GDP_per_capita','Family':'family','Health (Life Expectancy)':'Health_life_expectancy','Freedom':'freedom','Generosity':'generosity','Trust (Goverment Corruption)':'goverment_corruption'},axis=1)

# %%
happy_df.head()
# Out:
#   country_name          region  happiness_score  Economy_GDP_per_capita  \
# 0  Switzerland  Western Europe            7.587                 1.39651
# 1      Iceland  Western Europe            7.561                 1.30232
# 2      Denmark  Western Europe            7.527                 1.32548
# 3       Norway  Western Europe            7.522                 1.45900
# 4       Canada   North America            7.427                 1.32629
#
#     family  Health_life_expectancy  freedom  generosity  \
# 0  1.34951                 0.94143  0.66557     0.29678
# 1  1.40223                 0.94784  0.62877     0.43630
# 2  1.36058                 0.87464  0.64938     0.34139
# 3  1.33095                 0.88521  0.66973     0.34699
# 4  1.32261                 0.90563  0.63297     0.45811
#
#    Trust (Government Corruption)
# 0                        0.41978
# 1                        0.14145
# 2                        0.48357
# 3                        0.36503
# 4                        0.32957

# %%
happy_df=happy_df.rename(columns={'Trust (Government Corruption)':'trust_goverment'})
happy_df.head()
# Out:
#   country_name          region  happiness_score  Economy_GDP_per_capita  \
# 0  Switzerland  Western Europe            7.587                 1.39651
# 1      Iceland  Western Europe            7.561                 1.30232
# 2      Denmark  Western Europe            7.527                 1.32548
# 3       Norway  Western Europe            7.522                 1.45900
# 4       Canada   North America            7.427                 1.32629
#
#     family  Health_life_expectancy  freedom  generosity  trust_goverment
# 0  1.34951                 0.94143  0.66557     0.29678          0.41978
# 1  1.40223                 0.94784  0.62877     0.43630          0.14145
# 2  1.36058                 0.87464  0.64938     0.34139          0.48357
# 3  1.33095                 0.88521  0.66973     0.34699          0.36503
# 4  1.32261                 0.90563  0.63297     0.45811          0.32957

# %%
happy_df.isnull().sum()
# Out:
# country_name              0
# region                    0
# happiness_score           0
# Economy_GDP_per_capita    0
# family                    0
# Health_life_expectancy    0
# freedom                   0
# generosity                0
# trust_goverment           0
# dtype: int64

# %%
#Scatterplot for GDP per Capita and Happiness Score.
plt.rcParams['figure.figsize']=(15,7)
plt.title('ploting Happiness Score vs GDP')
sns.scatterplot(x=happy_df.happiness_score, y=happy_df.Economy_GDP_per_capita, hue = happy_df.region,s=200);
plt.legend(loc='upper left',fontsize='10')
plt.xlabel('Happiness Score')
plt.ylabel('GDP per capita')
plt.show()

# %%
gdp_region=happy_df.groupby('region')['Economy_GDP_per_capita'].sum()
gdp_region
# Out:
# region
# Australia and New Zealand           2.58376
# Central and Eastern Europe         27.33071
# Eastern Asia                        6.91068
# Latin America and Caribbean        19.28994
# Middle East and Northern Africa    21.33947
# North America                       2.72080
# Southeastern Asia                   7.10149
# Southern Asia                       3.92340
# Sub-Saharan Africa                 15.21892
# Western Europe                     27.27051
# Name: Economy_GDP_per_capita, dtype: float64

# %%
correlation=happy_df.corr(method='pearson')
f,ax=plt.subplots(figsize=(10,9))
sns.heatmap(correlation,mask=np.zeros_like(correlation,dtype=np.bool),cmap="Blues",square=True,ax=ax)
# Out:
# C:\Users\91749\AppData\Local\Temp/ipykernel_9112/3165308093.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(correlation,mask=np.zeros_like(correlation,dtype=np.bool),cmap="Blues",square=True,ax=ax)
# <AxesSubplot:>

# %%
corruption=happy_df.groupby('region')[['trust_goverment']].mean()
corruption
# Out:
#                                  trust_goverment
# region
# Australia and New Zealand               0.392795
# Central and Eastern Europe              0.086674
# Eastern Asia                            0.127695
# Latin America and Caribbean             0.117172
# Middle East and Northern Africa         0.181702
# North America                           0.244235
# Southeastern Asia                       0.151276
# Southern Asia                           0.102536
# Sub-Saharan Africa                      0.123878
# Western Europe                          0.231463

# %%
plt.rcParams['figure.figsize']=(15,7)
plt.title('Govt. Corruption in various Region')
plt.xlabel('Regions',fontsize=14)
plt.ylabel('Corruption',fontsize=14)
plt.xticks(rotation=30,ha='right')
plt.bar(corruption.index, corruption.trust_goverment)
# Out:
# <BarContainer object of 10 artists>

# %%
top_10=happy_df.head(10)
bottom_10=happy_df.head(10)

# %%
fig, axes=plt.subplots(1,2, figsize=(16,6))
plt.tight_layout(pad=2)
xlabels=top_10.country_name
axes[0].set_title('Top 10 Happiest countries life expectancy')
axes[0].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x= top_10.country_name,y= top_10.Health_life_expectancy, ax=axes[0])
axes[0].set_xlabel('Country name')
axes[0].set_ylabel('Life expectancy')

xlabels=bottom_10.country_name
axes[0].set_title('Bottom 10 least Happiest countries life expectancy')
axes[0].set_xticklabels(xlabels,rotation=45,ha='left')
sns.barplot(x= bottom_10.country_name,y= bottom_10.Health_life_expectancy,ax=axes[0])
axes[0].set_xlabel('Country name')
axes[0].set_ylabel('Life expectancy')
# Out:
# C:\Users\91749\AppData\Local\Temp/ipykernel_9112/2232301627.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(xlabels, rotation=45, ha='right')
# Text(113.625, 0.5, 'Life expectancy')

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=happy_df.freedom, y=happy_df.happiness_score, hue=happy_df.region, s=200);
plt.legend(loc='upper left',fontsize='10')
plt.xlabel('Freedom')
plt.ylabel('Happiness Score')
plt.show()

# %%
country=happy_df.sort_values(by='trust_goverment').head(10)
plt.rcParams['figure.figsize']=(12,7)
plt.title(' Countries with most Govt. Corruption')
plt.xlabel('Country',fontsize=14)
plt.ylabel('Corruption',fontsize=14)
plt.xticks(rotation=30,ha='right')
plt.bar(corruption.index, corruption.trust_goverment)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=happy_df.happiness_score, y=happy_df.trust_goverment, hue=happy_df.region, s=200);
plt.legend(loc='upper left',fontsize='10')
plt.xlabel('Happiness Score')
plt.ylabel('Corruption')
plt.show()

# %%
happy_df.skew()
# Out:
# C:\Users\91749\AppData\Local\Temp/ipykernel_9112/763306558.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   happy_df.skew()
# happiness_score           0.097769
# Economy_GDP_per_capita   -0.317575
# family                   -1.006893
# Health_life_expectancy   -0.705328
# freedom                  -0.413462
# generosity                1.001961
# trust_goverment           1.385463
# dtype: float64

# %%
happy_df.describe()
# Out:
#        happiness_score  Economy_GDP_per_capita      family  \
# count       158.000000              158.000000  158.000000
# mean          5.375734                0.846137    0.991046
# std           1.145010                0.403121    0.272369
# min           2.839000                0.000000    0.000000
# 25%           4.526000                0.545808    0.856823
# 50%           5.232500                0.910245    1.029510
# 75%           6.243750                1.158448    1.214405
# max           7.587000                1.690420    1.402230
#
#        Health_life_expectancy     freedom  generosity  trust_goverment
# count              158.000000  158.000000  158.000000       158.000000
# mean                 0.630259    0.428615    0.237296         0.143422
# std                  0.247078    0.150693    0.126685         0.120034
# min                  0.000000    0.000000    0.000000         0.000000
# 25%                  0.439185    0.328330    0.150553         0.061675
# 50%                  0.696705    0.435515    0.216130         0.107220
# 75%                  0.811013    0.549092    0.309883         0.180255
# max                  1.025250    0.669730    0.795880         0.551910

# %%
plt.figure(figsize=(15,7))
sns.heatmap(happy_df.describe(), annot=True,linewidth=0.2, linecolor='white',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
happy_df.corr()
# Out:
#                         happiness_score  Economy_GDP_per_capita    family  \
# happiness_score                1.000000                0.780966  0.740605
# Economy_GDP_per_capita         0.780966                1.000000  0.645299
# family                         0.740605                0.645299  1.000000
# Health_life_expectancy         0.724200                0.816478  0.531104
# freedom                        0.568211                0.370300  0.441518
# generosity                     0.180319               -0.010465  0.087513
# trust_goverment                0.395199                0.307885  0.205605
#
#                         Health_life_expectancy   freedom  generosity  \
# happiness_score                       0.724200  0.568211    0.180319
# Economy_GDP_per_capita                0.816478  0.370300   -0.010465
# family                                0.531104  0.441518    0.087513
# Health_life_expectancy                1.000000  0.360477    0.108335
# freedom                               0.360477  1.000000    0.373916
# generosity                            0.108335  0.373916    1.000000
# trust_goverment                       0.248335  0.493524    0.276123
#
#                         trust_goverment
# happiness_score                0.395199
# Economy_GDP_per_capita         0.307885
# family                         0.205605
# Health_life_expectancy         0.248335
# freedom                        0.493524
# generosity                     0.276123
# trust_goverment                1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(happy_df.corr(), annot=True, linewidth=0.1,linecolor='white',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
happy_df.corr()['happiness_score'].sort_values(ascending=False).drop(['happiness_score']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names', fontsize=14)
plt.title('correlation',fontsize=15)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
happy_df.skew()
# Out:
# happiness_score           0.097769
# Economy_GDP_per_capita   -0.317575
# family                   -1.006893
# Health_life_expectancy   -0.705328
# freedom                  -0.413462
# generosity                1.001961
# trust_goverment           1.385463
# dtype: float64

# %%
happy_df.dtypes
# Out:
# country_name               object
# region                     object
# happiness_score           float64
# Economy_GDP_per_capita    float64
# family                    float64
# Health_life_expectancy    float64
# freedom                   float64
# generosity                float64
# trust_goverment           float64
# dtype: object

# %%
happy_df.columns
# Out:
# Index(['country_name', 'region', 'happiness_score', 'Economy_GDP_per_capita',
#        'family', 'Health_life_expectancy', 'freedom', 'generosity',
#        'trust_goverment'],
#       dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in happy_df.columns:
    if happy_df[i].dtypes=="object":
        happy_df[i]=enc.fit_transform(happy_df[i].values.reshape(-1,1))
happy_df
# Out:
#      country_name  region  happiness_score  Economy_GDP_per_capita   family  \
# 0           135.0     9.0            7.587                 1.39651  1.34951
# 1            58.0     9.0            7.561                 1.30232  1.40223
# 2            37.0     9.0            7.527                 1.32548  1.36058
# 3           105.0     9.0            7.522                 1.45900  1.33095
# 4            24.0     5.0            7.427                 1.32629  1.32261
# ..            ...     ...              ...                     ...      ...
# 153         118.0     8.0            3.465                 0.22208  0.77370
# 154          13.0     8.0            3.340                 0.28665  0.35386
# 155         136.0     4.0            3.006                 0.66320  0.47489
# 156          21.0     8.0            2.905                 0.01530  0.41587
# 157         141.0     8.0            2.839                 0.20868  0.13995
#
#      Health_life_expectancy  freedom  generosity  trust_goverment
# 0                   0.94143  0.66557     0.29678          0.41978
# 1                   0.94784  0.62877     0.43630          0.14145
# 2                   0.87464  0.64938     0.34139          0.48357
# 3                   0.88521  0.66973     0.34699          0.36503
# 4                   0.90563  0.63297     0.45811          0.32957
# ..                      ...      ...         ...              ...
# 153                 0.42864  0.59201     0.22628          0.55191
# 154                 0.31910  0.48450     0.18260          0.08010
# 155                 0.72193  0.15684     0.47179          0.18906
# 156                 0.22396  0.11850     0.19727          0.10062
# 157                 0.28443  0.36453     0.16681          0.10731
#
# [158 rows x 9 columns]

# %%
# outlier detection using boxplot

# %%
happy_df['happiness_score'].plot.box()
# Out:
# <AxesSubplot:>

# %%
happy_df['Economy_GDP_per_capita'].plot.box()
# Out:
# <AxesSubplot:>

# %%
happy_df['family'].plot.box()
# Out:
# <AxesSubplot:>

# %%
happy_df['Health_life_expectancy'].plot.box()
# Out:
# <AxesSubplot:>

# %%
happy_df['freedom'].plot.box()
# Out:
# <AxesSubplot:>

# %%
happy_df['generosity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
happy_df['trust_goverment'].plot.box()
# Out:
# <AxesSubplot:>

# %%
happy_df.shape
# Out:
# (158, 9)

# %%
from scipy.stats import zscore
z=np.abs(zscore(happy_df))
threshold=3
np.where(z>3)
# Out:
# (array([ 27, 128, 147, 153, 157], dtype=int64),
#  array([8, 7, 4, 8, 4], dtype=int64))

# %%
happy_df_new_z=happy_df[(z<3).all(axis=1)]
happy_df_new_z
# Out:
#      country_name  region  happiness_score  Economy_GDP_per_capita   family  \
# 0           135.0     9.0            7.587                 1.39651  1.34951
# 1            58.0     9.0            7.561                 1.30232  1.40223
# 2            37.0     9.0            7.527                 1.32548  1.36058
# 3           105.0     9.0            7.522                 1.45900  1.33095
# 4            24.0     5.0            7.427                 1.32629  1.32261
# ..            ...     ...              ...                     ...      ...
# 151          20.0     8.0            3.587                 0.25812  0.85188
# 152           0.0     7.0            3.575                 0.31982  0.30285
# 154          13.0     8.0            3.340                 0.28665  0.35386
# 155         136.0     4.0            3.006                 0.66320  0.47489
# 156          21.0     8.0            2.905                 0.01530  0.41587
#
#      Health_life_expectancy  freedom  generosity  trust_goverment
# 0                   0.94143  0.66557     0.29678          0.41978
# 1                   0.94784  0.62877     0.43630          0.14145
# 2                   0.87464  0.64938     0.34139          0.48357
# 3                   0.88521  0.66973     0.34699          0.36503
# 4                   0.90563  0.63297     0.45811          0.32957
# ..                      ...      ...         ...              ...
# 151                 0.27125  0.39493     0.21747          0.12832
# 152                 0.30335  0.23414     0.36510          0.09719
# 154                 0.31910  0.48450     0.18260          0.08010
# 155                 0.72193  0.15684     0.47179          0.18906
# 156                 0.22396  0.11850     0.19727          0.10062
#
# [153 rows x 9 columns]

# %%
happy_df_new_z.shape
# Out:
# (153, 9)

# %%
Data_loss=((158-153)/158)*100
Data_loss
# Out:
# 3.1645569620253164

# %%
features=happy_df.drop(["country_name","region","happiness_score"], axis=1)
target = happy_df["happiness_score"]

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test= train_test_split(features,target,test_size=0.2, random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i}, the training accuracy is:{r2_score(target_train,pred_train)}")
    print(f"At random state {i}, the training accuracy is:{r2_score(target_test,pred_test)}")
    print('\n')
# Out:
# At random state 0, the training accuracy is:0.7934954655229758
# At random state 0, the training accuracy is:0.674959293275678
#
#
# At random state 1, the training accuracy is:0.7599584958477715
# At random state 1, the training accuracy is:0.8497886631884372
#
#
# At random state 2, the training accuracy is:0.7788420871167522
# At random state 2, the training accuracy is:0.7571057958032004
#
#
# At random state 3, the training accuracy is:0.7709602714133003
# At random state 3, the training accuracy is:0.7877156496246467
#
#
# At random state 4, the training accuracy is:0.76531460388099
# At random state 4, the training accuracy is:0.751582045886779
#
#
# At random state 5, the training accuracy is:0.7816671100709468
# At random state 5, the training accuracy is:0.7323616662575567
#
#
# At random state 6, the training accuracy is:0.7715220369209751
# At random state 6, the training accuracy is:0.7919207631013564
#
#
# At random state 7, the training accuracy is:0.7868537788780873
# At random state 7, the training accuracy is:0.7148110402535658
#
#
# At random state 8, the training accuracy is:0.7807555106741613
# At random state 8, the training accuracy is:0.7524863956099235
#
#
# At random state 9, the training accuracy is:0.7914241097166472
# At random state 9, the training accuracy is:0.6812476874214011
#
#
# At random state 10, the training accuracy is:0.7727116073684922
# At random state 10, the training accuracy is:0.7891017281595928
#
#
# At random state 11, the training accuracy is:0.7752010882268997
# At random state 11, the training accuracy is:0.7708775698116603
#
#
# At random state 12, the training accuracy is:0.7871408831814082
# At random state 12, the training accuracy is:0.734871304079832
#
#
# At random state 13, the training accuracy is:0.7997690962193998
# At random state 13, the training accuracy is:0.6690597033011069
#
#
# At random state 14, the training accuracy is:0.762346395850662
# At random state 14, the training accuracy is:0.8192561866575551
#
#
# At random state 15, the training accuracy is:0.7656431943531625
# At random state 15, the training accuracy is:0.8127130719625139
#
#
# At random state 16, the training accuracy is:0.7759109042081295
# At random state 16, the training accuracy is:0.7628378048995273
#
#
# At random state 17, the training accuracy is:0.7693763137498935
# At random state 17, the training accuracy is:0.7835125320231329
#
#
# At random state 18, the training accuracy is:0.7579528970223881
# At random state 18, the training accuracy is:0.8295531674742118
#
#
# At random state 19, the training accuracy is:0.7766939632587846
# At random state 19, the training accuracy is:0.7676518284335283
#
#
# At random state 20, the training accuracy is:0.8068717203212818
# At random state 20, the training accuracy is:0.6095812881905931
#
#
# At random state 21, the training accuracy is:0.8002984015893726
# At random state 21, the training accuracy is:0.6824647398675292
#
#
# At random state 22, the training accuracy is:0.8036532989090661
# At random state 22, the training accuracy is:0.645846564074849
#
#
# At random state 23, the training accuracy is:0.7778074530661963
# At random state 23, the training accuracy is:0.7502782022815152
#
#
# At random state 24, the training accuracy is:0.7645832542106845
# At random state 24, the training accuracy is:0.8196511294826013
#
#
# At random state 25, the training accuracy is:0.7908885378399965
# At random state 25, the training accuracy is:0.6659148732933295
#
#
# At random state 26, the training accuracy is:0.7794011704867272
# At random state 26, the training accuracy is:0.741530973570721
#
#
# At random state 27, the training accuracy is:0.7943624883567451
# At random state 27, the training accuracy is:0.6904683025122667
#
#
# At random state 28, the training accuracy is:0.7966326647420777
# At random state 28, the training accuracy is:0.6090230428091323
#
#
# At random state 29, the training accuracy is:0.7867729532866172
# At random state 29, the training accuracy is:0.7125729218735706
#
#
# At random state 30, the training accuracy is:0.7788479397831598
# At random state 30, the training accuracy is:0.7496819217114832
#
#
# At random state 31, the training accuracy is:0.7896285005000456
# At random state 31, the training accuracy is:0.7055394783425961
#
#
# At random state 32, the training accuracy is:0.7913444151485562
# At random state 32, the training accuracy is:0.7119619957273313
#
#
# At random state 33, the training accuracy is:0.7869765848334875
# At random state 33, the training accuracy is:0.7095576557773207
#
#
# At random state 34, the training accuracy is:0.7732825927072988
# At random state 34, the training accuracy is:0.7385359657128603
#
#
# At random state 35, the training accuracy is:0.7942411401926106
# At random state 35, the training accuracy is:0.6962743668401843
#
#
# At random state 36, the training accuracy is:0.7994371533388049
# At random state 36, the training accuracy is:0.5817187560925318
#
#
# At random state 37, the training accuracy is:0.7616536961354405
# At random state 37, the training accuracy is:0.8177119808690633
#
#
# At random state 38, the training accuracy is:0.8055082234043985
# At random state 38, the training accuracy is:0.5299330255518555
#
#
# At random state 39, the training accuracy is:0.7661833632360712
# At random state 39, the training accuracy is:0.8039745345300331
#
#
# At random state 40, the training accuracy is:0.7876299808756045
# At random state 40, the training accuracy is:0.6968560132541608
#
#
# At random state 41, the training accuracy is:0.8021314353997967
# At random state 41, the training accuracy is:0.6653372743929972
#
#
# At random state 42, the training accuracy is:0.7599211419054285
# At random state 42, the training accuracy is:0.8294705100069293
#
#
# At random state 43, the training accuracy is:0.7832007754766345
# At random state 43, the training accuracy is:0.732513243022083
#
#
# At random state 44, the training accuracy is:0.7684313208389573
# At random state 44, the training accuracy is:0.7984084650222818
#
#
# At random state 45, the training accuracy is:0.799602286555035
# At random state 45, the training accuracy is:0.6693566154820788
#
#
# At random state 46, the training accuracy is:0.8012787959470479
# At random state 46, the training accuracy is:0.6846817348000884
#
#
# At random state 47, the training accuracy is:0.775005875232883
# At random state 47, the training accuracy is:0.7599124888391051
#
#
# At random state 48, the training accuracy is:0.82716890951342
# At random state 48, the training accuracy is:0.5216245233611609
#
#
# At random state 49, the training accuracy is:0.7715424106618254
# At random state 49, the training accuracy is:0.7955330168017656
#
#
# At random state 50, the training accuracy is:0.7659641695963196
# At random state 50, the training accuracy is:0.794813623766977
#
#
# At random state 51, the training accuracy is:0.790050050483837
# At random state 51, the training accuracy is:0.6932827235135657
#
#
# At random state 52, the training accuracy is:0.752193079263394
# At random state 52, the training accuracy is:0.8647249415884456
#
#
# At random state 53, the training accuracy is:0.8218525106378876
# At random state 53, the training accuracy is:0.48443675806938713
#
#
# At random state 54, the training accuracy is:0.744472873626914
# At random state 54, the training accuracy is:0.8486710068552454
#
#
# At random state 55, the training accuracy is:0.7735307005115851
# At random state 55, the training accuracy is:0.7905085657400119
#
#
# At random state 56, the training accuracy is:0.7603047409837774
# At random state 56, the training accuracy is:0.8258958260627152
#
#
# At random state 57, the training accuracy is:0.7815139902837669
# At random state 57, the training accuracy is:0.7479452792175227
#
#
# At random state 58, the training accuracy is:0.8071709073302351
# At random state 58, the training accuracy is:0.5918762798946745
#
#
# At random state 59, the training accuracy is:0.7920015368518107
# At random state 59, the training accuracy is:0.6714369042471393
#
#
# At random state 60, the training accuracy is:0.7768060935514423
# At random state 60, the training accuracy is:0.7657856671218314
#
#
# At random state 61, the training accuracy is:0.7535584956034913
# At random state 61, the training accuracy is:0.8350711315090256
#
#
# At random state 62, the training accuracy is:0.7955133105386526
# At random state 62, the training accuracy is:0.5972365960909587
#
#
# At random state 63, the training accuracy is:0.7938377684439978
# At random state 63, the training accuracy is:0.6353572210945024
#
#
# At random state 64, the training accuracy is:0.771410795923553
# At random state 64, the training accuracy is:0.785488262549577
#
#
# At random state 65, the training accuracy is:0.7958007943222783
# At random state 65, the training accuracy is:0.6811367815063882
#
#
# At random state 66, the training accuracy is:0.7816774064377927
# At random state 66, the training accuracy is:0.7209333316061621
#
#
# At random state 67, the training accuracy is:0.7735340923312322
# At random state 67, the training accuracy is:0.7510072596844521
#
#
# At random state 68, the training accuracy is:0.7799143838457766
# At random state 68, the training accuracy is:0.7553803226375345
#
#
# At random state 69, the training accuracy is:0.7755236762499027
# At random state 69, the training accuracy is:0.7551219888075159
#
#
# At random state 70, the training accuracy is:0.7830290647560717
# At random state 70, the training accuracy is:0.723170407414065
#
#
# At random state 71, the training accuracy is:0.7856721356188466
# At random state 71, the training accuracy is:0.6918146390819271
#
#
# At random state 72, the training accuracy is:0.7218577026656996
# At random state 72, the training accuracy is:0.8906689060705234
#
#
# At random state 73, the training accuracy is:0.786422635848624
# At random state 73, the training accuracy is:0.7238348944931658
#
#
# At random state 74, the training accuracy is:0.7842993666373814
# At random state 74, the training accuracy is:0.7094926451331954
#
#
# At random state 75, the training accuracy is:0.7830783987981857
# At random state 75, the training accuracy is:0.7250920439523736
#
#
# At random state 76, the training accuracy is:0.8065287420021952
# At random state 76, the training accuracy is:0.5619105414475359
#
#
# At random state 77, the training accuracy is:0.8090239504439491
# At random state 77, the training accuracy is:0.584506907550448
#
#
# At random state 78, the training accuracy is:0.8118120291150915
# At random state 78, the training accuracy is:0.5358107697112282
#
#
# At random state 79, the training accuracy is:0.7948266346253724
# At random state 79, the training accuracy is:0.6770907575623497
#
#
# At random state 80, the training accuracy is:0.7629380841334895
# At random state 80, the training accuracy is:0.7973049029062214
#
#
# At random state 81, the training accuracy is:0.784453400650764
# At random state 81, the training accuracy is:0.7363829487394211
#
#
# At random state 82, the training accuracy is:0.7876533109737154
# At random state 82, the training accuracy is:0.7241536037918193
#
#
# At random state 83, the training accuracy is:0.7898842234507422
# At random state 83, the training accuracy is:0.6850037606031758
#
#
# At random state 84, the training accuracy is:0.7593002747260564
# At random state 84, the training accuracy is:0.8279979245308402
#
#
# At random state 85, the training accuracy is:0.8181762071815581
# At random state 85, the training accuracy is:0.48109791846770567
#
#
# At random state 86, the training accuracy is:0.7722260734422206
# At random state 86, the training accuracy is:0.7866748879433356
#
#
# At random state 87, the training accuracy is:0.7778481790292519
# At random state 87, the training accuracy is:0.7533454724732882
#
#
# At random state 88, the training accuracy is:0.7956307676570538
# At random state 88, the training accuracy is:0.6591081547097167
#
#
# At random state 89, the training accuracy is:0.8077757777684149
# At random state 89, the training accuracy is:0.614224620919356
#
#
# At random state 90, the training accuracy is:0.7801760665905096
# At random state 90, the training accuracy is:0.7233201726977738
#
#
# At random state 91, the training accuracy is:0.7963442451282475
# At random state 91, the training accuracy is:0.6675163107191018
#
#
# At random state 92, the training accuracy is:0.7961274216277676
# At random state 92, the training accuracy is:0.6514518411785979
#
#
# At random state 93, the training accuracy is:0.7679179484284453
# At random state 93, the training accuracy is:0.8050249548151661
#
#
# At random state 94, the training accuracy is:0.7966638355060045
# At random state 94, the training accuracy is:0.6067998395222065
#
#
# At random state 95, the training accuracy is:0.8039322710525958
# At random state 95, the training accuracy is:0.6167284012901886
#
#
# At random state 96, the training accuracy is:0.7907395572273791
# At random state 96, the training accuracy is:0.6930115647648062
#
#
# At random state 97, the training accuracy is:0.77505442173126
# At random state 97, the training accuracy is:0.7774812591479401
#
#
# At random state 98, the training accuracy is:0.8073586927171362
# At random state 98, the training accuracy is:0.5779101958182981
#
#
# At random state 99, the training accuracy is:0.7746591036615215
# At random state 99, the training accuracy is:0.7567118290227406

# %%
happy_df.mean()
# Out:
# country_name              78.500000
# region                     5.120253
# happiness_score            5.375734
# Economy_GDP_per_capita     0.846137
# family                     0.991046
# Health_life_expectancy     0.630259
# freedom                    0.428615
# generosity                 0.237296
# trust_goverment            0.143422
# dtype: float64

# %%
features_train,features_test,target_train,target_test= train_test_split(features,target,test_size=0.2, random_state=72)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.8906689060705234
